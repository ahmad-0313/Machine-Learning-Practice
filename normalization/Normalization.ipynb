# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Class label', axis=1),
                                                    df['Class label'],
                                                    test_size=0.3,
                                                    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((124, 2), (54, 2))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=X_test.columns)

# %%
X_train_scaled.describe()
# Out:
#           Alcohol  Malic acid
# count  124.000000  124.000000
# mean     0.525017    0.313805
# std      0.215414    0.238802
# min      0.000000    0.000000
# 25%      0.358199    0.150735
# 50%      0.540323    0.209034
# 75%      0.701613    0.495273
# max      1.000000    1.000000

# %%
# !git clone https://github.com/ahmad-0313/Machine-Learning-Practice.git
# Out:
# Cloning into 'Machine-Learning-Practice'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 7 (delta 0), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), 5.06 KiB | 5.06 MiB/s, done.

# %%
# !mkdir -p /content/Machine-Learning-Practice/normalization

# %%
# !cp /content/wine_data.csv /content/Machine-Learning-Practice/normalization/

# %%
# !cp /content/*.ipynb /content/Machine-Learning-Practice/normalization/
# Out:
# cp: cannot stat '/content/*.ipynb': No such file or directory

# %%
# !find /content -name "*.ipynb"
# Out:
# /content/Machine-Learning-Practice/Standarization/Standardization.ipynb

# %%
# !find /content -name "*.ipynb"
